# %% [markdown]
# # La collecte automatique de données sur le Web

# %% [markdown]
# Avant de commencer à nous attaquer à de belles pages web (html), nous allons decouvrir le langage xml qui est une bonne introduction au data web scraping

# %% [markdown]
# ### Le XML

# %% [markdown]
# Le XML a été créé pour faciliter les échanges de données entre les machines et les logiciels.
#
# Le XML est un langage qui s'écrit à l'aide de balises.
#
# Le XML est une recommandation du W3C, il s'agit donc d'une technologie avec des règles strictes à respecter.
#
# Le XML se veut compréhensible par tous : les hommes comme les machines.
#
# Le XML nous permet de créer notre propre vocabulaire grâce à un ensemble de règles et de balises personnalisables.

# %% [markdown]
# Le XML se veut également compatible avec le web afin que les échanges de données puissent se faire facilement à travers le réseau Internet.
#
# Le XML se veut donc standardisé, simple, mais surtout extensible et configurable afin que n'importe quel type de données puisse être décrit.

# %% [markdown]
# Voici un exemple de document XML, que nous avons enregistré sous le nom de data.xml dans le repertoire data
#
# Affichez son contenu

# %%
fichier = open("data.xml", "r")
print (fichier.read())
fichier.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <users>
#     <user data-id="101">
#         <nom>Zorro</nom>
#         <metier>Danseur</metier>
#     </user>
#     <user data-id="102">
#         <nom>Hulk</nom>
#         <metier>Footballeur</metier>
#     </user>
#     <user data-id="103">
#         <nom>Zidane</nom>
#         <metier>Star</metier>
#     </user>
#     <user data-id="104">
#         <nom>Beans</nom>
#         <metier>Epicier</metier>
#     </user>
#     <user data-id="105">
#         <nom>Batman</nom>
#         <metier>Veterinaire</metier>
#     </user>
#     <user data-id="106">
#         <nom>Spiderman</nom>
#         <metier>Veterinaire</metier>
#     </user>
# </users>

# %% [markdown]
# La première ligne indique l' encodage , on reste toujours dans l' encodage UTF-8 . Ensuite on remarque que la balise "users" possède d'autres balises "user" qui elles même possèdent leurs propres balises. Les données sont hiérarchisées dans un arbre et chaque noeud apporte une information.

# %% [markdown]
# Voici un petit script qui affiche tous les noms des user .

# %%
from lxml import etree
# Je definis mon document source
tree = etree.parse("data.xml")
# je regarde mon document et j'identifie le chemin de balise pour arriver à l'information "user"
# En effet, l'information se trouve dans une balise nom elle meme presente dans une balise user
# elle meme presente dans une balise users. Cette derniere balise se trouvant à la racine du repertoire
# donc dans tree.xpath("/users/user/nom") il y a les balises associées à notre recherche
for user in tree.xpath("/users/user/metier"):
    # Je souhaite afficher uniquement le contenu (.text) de ces balises /users/user/metier
    print(user.text)
# Out:
# Danseur
# Footballeur
# Star
# Epicier
# Veterinaire
# Veterinaire

# %%
tree.xpath("/users/user/nom")[4].text
# Out:
# 'Batman'

# %%
#Vous pouvez afficher les attributs des balises qui stocke ces informations
tree = etree.parse("data.xml")
for user in tree.xpath("/users/user"):
    print(user.get("data-id"))
# Out:
# 101
# 102
# 103
# 104
# 105
# 106

# %% [markdown]
# Vous pouvez affiner l'affichage en proposant de n'afficher que les user dont le métier est Veterinaire

# %%
tree = etree.parse("data.xml")
# Quel joli petit dictionnaire
for user in tree.xpath("/users/user[metier='Veterinaire']/nom"):
    print(user.text)
# Out:
# Batman
# Spiderman

# %% [markdown]
# # Data web scrapping

# %% [markdown]
# Nous avons vu précédemment comment parser du XML , il est également possible de parser du HTML et l'outil qui fait le mieux le job selon moi c'est le librairy BeautifulSoup

# %% [markdown]
# Enregistrer une page web (par exemple lequipe.fr) que vous aimez bien dans le repertoire data, et afficher son contenu (le fichier xxx.html)
#
# Mettez le contenu de cette page dans une variable, par exemple html_doc

# %%
html_doc = open("l_equipe_l_actualite_du_sport_en_continu.html", "r")

# %% [markdown]
# ### Recuperer les titres des news

# %%
from bs4 import BeautifulSoup

#html_doc = open("l_equipe_l_actualite_du_sport_en_continu.html", "r")
soup = BeautifulSoup(html_doc)
# Dans mon fichier (lequipe.fr) en regardant ce script html Nous pouvons voir que le titre principal est rangé 
# dans la balise h1
for p in soup.find_all('link'):
    # Nous récupérons uniquement le contenu ==> .text
    print (p.get("href"))
# Out:
# https://www.lequipe.fr/
# https://xe2jlmuyam.kameleoon.eu/kameleoon.js
# https://www.lequipe.fr/
# https://m.lequipe.fr/
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-57x57.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-60x60.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-72x72.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-76x76.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-114x114.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-120x120.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-144x144.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-152x152.png?140917
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-180x180.png?140917
# http://www.lequipe.fr/elements/img/favicons/favicon-32x32.png?140917
# http://www.lequipe.fr/elements/img/favicons/android-chrome-192x192.png?140917
# http://www.lequipe.fr/elements/img/favicons/favicon-96x96.png?140917
# http://www.lequipe.fr/elements/img/favicons/favicon-16x16.png?140917
# http://www.lequipe.fr/elements/img/favicons/manifest.json
# http://www.lequipe.fr/elements/img/favicons/apple-touch-icon-16x16.png
# ./L'ÉQUIPE - L'actualité du sport en continu._files/style-cch-20190523145742.min.css
# ./L'ÉQUIPE - L'actualité du sport en continu._files/widget.css
# ./L'ÉQUIPE - L'actualité du sport en continu._files/f.txt
# ./L'ÉQUIPE - L'actualité du sport en continu._files/f(1).txt
# http://tpc.googlesyndication.com/safeframe/1-0-33/html/container.html
# ./L'ÉQUIPE - L'actualité du sport en continu._files/pulpix.css
# https://www.lequipe.fr/elements/img/favicons/manifest.json

# %% [markdown]
# Toujours sur l'equipe.fr, pourrez vous afficher les descriptions d'articles situés sous les sousitre, s'ily en a

# %%
#html_doc = open("l_equipe_l_actualite_du_sport_en_continu.html", "r")

for p in soup.find_all('p', attrs={"class" : "home__colead__details"}):
    print (p.text)
# Out:
#     Avec deux cols et une arrivée à 2247 m d'altitude, l'étape reliant Pignerol à Ceresole Reale (196 km) devrait permettre aux grimpeurs de se montrer. A suivre en direct.
#
#
#     Le premier col du Giro a montré que Primoz Roglic devra se débrouiller seul jusqu'à Vérone : collectivement, ses rivaux sont mieux armés.
#
#
#     Les clubs ont changé d'entraîneur à huit reprises cette saison en Ligue 1. Certains, comme Monaco et Bordeaux, ont même limogé deux techniciens. Pas un record mais une hausse significative.
#
#
#     Sans club depuis sa dernière expérience au Shanghai SIPG (Chine), l'entraîneur portugais André Villas-Boas, n'a pas caché son intérêt pour le projet marseillais.
#
#
#     Les arrivées en cours de saison d'Antoine Kombouaré à Dijon et de Rolland Courbis à Caen devaient permettre aux deux clubs d'éviter la relégation. Mais ils ne sont pas sauvés avant la dernière journée.
#
#
#     Le classement de la saison tient pour 25 % dans le calcul de la répartition des droits audiovisuels domestiques en Ligue 1. Il y aura quelques centaines de milliers d'euros à aller chercher, vendredi soir.
#
#
#     Eddy Gnahoré, le milieu amiénois (25 ans), a connu onze clubs dans sa carrière. Il évoque son cheminement et l'influence souvent néfaste qu'ont eue certains représentants.
#
#
#     Vendredi, face à Montpellier, l'entraîneur marseillais fera ses adieux à l'Orange Vélodrome. Surprise : son bilan en Ligue 1 y est plus positif que celui de ses prédécesseurs.
#
#
#     Plutôt que l'option Printant-Sablé défendue par Roland Romeyer, le président du conseil de surveillance de l'ASSE préférerait attirer un entraîneur de renom pour succéder à Jean-Louis Gasset.
#
#
#     Malgré des changements attendus cet été, l'OL pourra également s'appuyer la saison prochaine sur des éléments d'avenir destinés à jouer un rôle encore plus important.
#
#
#     Christophe Galtier, entraîneur du LOSC, salue la tenue du vestiaire lillois et dévoile les coulisses de la course à la deuxième place.
#
#
#     Deux artistes parfois incompris sont ici réunis : le rappeur Disiz (41 ans) et le footballeur Hatem Ben Arfa (32 ans). Les deux hommes ont percé, brillé très jeune mais leur carrière est, depuis, tout sauf linéaire. Rencontre avec deux créatifs, touchants de sincérité.
#
#
#     Alexandre Müller, 22 ans, a validé son billet pour le grand tableau après son succès sur Viktor Troicki (6-3, 6-4).
#
#
#     En 1989, un gamin de 17 ans humiliait avec un service improbable le n°1 mondial, Ivan Lendl, avant de remporter Roland-Garros.Trente ans après, l'Américain nous raconte avec émotion la quinzaine qui a changé sa vie.
#
#
#     Rapide et endurante, la Roumaine Simona Halep a enlevé Roland-Garros 2018 grâce à de vraies qualités d'athlète. Et dire qu'elle déteste la préparation physique... Nous sommes allés vérifier.
#
#
#     Le 26 mai 2003, face au Péruvien Luis Horna, Federer passe en quelques heures du statut de favori du tournoi à celui de loser en Grand Chelem.
#
#
#     Samedi, pour la dernière journée du Top 14, le MHR se déplace à Clermont avec l'espoir de décrocher son billet pour les phases finales. Le défi est immense car personne n'a gagné au Michelin cette saison. Mais Montpellier y a remporté ses quatre derniers matches.
#
#
#     William Servat a officialisé ce vendredi dans nos colonnes son arrivée dans le staff de l'équipe de France à l'issue de la prochaine Coupe du Monde (20 septembre-2 novembre 2019) au Japon. Retour sur la carrière internationale de l'ancien talonneur, riche de 49 sélections.
#
#
#     La phase régulière du Top 14 touche à sa fin pour bientôt laisser places aux phases finales, un enjeu économique essentiel pour les différents acteurs du championnat.
#
#
#     Détentrice des droits du championnat d'Angleterre à partir de la saison prochaine, la chaîne cryptée a obtenu l'autorisation de les partager avec RMC Sport. Avec une idée derrière la tête.
#
#
#     L'écurie française a avoué avoir connu un gros souci de fabrication sur son moteur 2019. Et c'est doté d'un nouveau groupe propulseur que les F1 françaises ont attaqué l'épreuve monégasque.
#
# Charles Leclerc décrochera-t-il une place sur le podium du Grand Prix de Monaco, dimanche ?
#
#     Très populaire, le Grand Prix de Monaco, course de Formule 1 la plus glamour de l'année, est aussi un chemin de croix pour les télévisions.
#
#
#     Bluffé par la maturité de Charles Leclerc, le prince souverain revendique sa passion pour le pilote Ferrari. Surtout, il tance par avance ceux qui voudraient récupérer ses succès futurs. Le jeune homme est citoyen monégasque. Point final.
#
#
#     En affichant une générosité débordante sur le terrain et en dehors, Franck Ribéry s'est assuré une popularité énorme chez les fans du Bayern Munich. Depuis 2007 et malgré quelques velléités de départ, l'ailier est devenu une légende aux yeux du public bavarois.
#
#
#     Gaël Fickou, grand espoir du rugby français se confie sur son sport. Retour en image.
#
#
#     Dans sa chronique, l'ancien joueur du Tour européen et consultant sur la chaîne Golf + François Calmels décortique un fait de l'actualité du golf. Cette semaine, la victoire de Brooks Koepka à l'USPGA.
#
#
#     Si l'équipe de France n'a pas brillé, vendredi à Hohhot, la très précoce Japonaise Uta Abe (- 52 kg) s'est baladée.
#
#
#     Soixante-six heures après sa qualification face au Paris FC, Lens mesurera sa fraîcheur face à Troyes, 3e de Ligue 2, invaincu depuis février.
#
#
#     Les play-offs du Championnat de France débutent ce  soir. L'ASVEL, leader du classement, et Monaco, exceptionnel sur la phase retour, sont favoris. Décryptage de chaque série.
#
#
#     Ancien conseiller de Louis Nicollin, Jean-Marc Leynet est l'expert incontournable des ventes aux enchères d'objets sportifs. Vendredi et samedi, une importante vente a lieu à Drouot, avec notamment un maillot de Zinédine Zidane.
#
#
#     Le défenseur international français pourrait quitter Arsenal à un an de la fin de son contrat.
#
#
#     Si sa mise en examen est ennuyeuse pour son image, Nasser al-Khelaïfi conserve pour l'instant la confiance de ses dirigeants. Au nom de la présomption d'innocence.
#
#
#     En déroulant le fil de ce qui n'était au départ qu'une simple affaire de dopage étouffée, le juge Renaud Van Ruymbeke a découvert nombres de scandales dont le dernier rebondissement est la mise en examen de Nasser al-Khelaïfi.
#
#
#     L'avocat de Nasser al-Khelaïfi estime que le juge Renaud van Ruymbeke, qui a mis en examen le président du PSG pour «corruption active», fait fausse route.
#
#
#     Après leur succès à Milwaukee (105-99) jeudi soir, les Raptors mènent (3-2) en finale de la Conférence Est. Et le prochain match aura lieu à Toronto.
#
#
#     L'épreuve qui oppose une équipe d'Europe à une équipe du reste du monde bénéficiera de la logistique de l'ATP, sans distribuer pour autant de points au classement mondial.
#
#
#     Les places pour assister à la finale de la Ligue Europa entre Arsenal et Chelsea à Bakou (Azerbaïdjan) sont une denrée rare et souvent très coûteuse. De Londres à Bakou, entre peines, sacrifices et excitation, cette finale divise les supporters des Blues et des Gunners.
#
#
#     Les fongicides, utilisés pour éradiquer certaines maladies des pelouses des clubs professionnels, présentent également un risque pour l'environnement, alors qu'une solution existe pour éviter qu'ils contaminent les nappes phréatiques.
#
#
#     Nikola Karabatic a été opéré ce vendredi matin de la cheville gauche. Il manquera  les deux matches des Bleus qualificatifs à l'Euro 2020 en Lituanie et face à la Roumanie mi-juin.
#
#
#     La Fédération française de foot lance une grande campagne de communication autour des Bleues, une semaine avant leur entrée en lice dans la Coupe du monde face à la Corée du Sud.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Le documentaire « Emiliano Sala, les secrets d'un destin brisé », diffusé mercredi à 21 heures sur la chaîne L'Équipe, révèle un message vocal de l'attaquant argentin à ses proches le 6 janvier. Il y exprime sa rancoeur envers Waldemar Kita, le président du FC Nantes.
#
#
#     Découvrez l'enquête exclusive sur les circonstances qui ont conduit à la disparition d'Emiliano Sala dans le sujet « Emiliano Sala, les secrets d'un destin brisé » de l'émission L'Équipe Enquête, diffusée à 21 heures, ce mercredi, sur la chaîne L'Équipe.
#
#
#     Après la diffusion du documentaire « Emiliano Sala, les secrets d'un destin brisé » de l'Équipe Enquête, Waldemar Kita a répondu aux questions de Sébastien Tarrago.
#
#
#     Deux artistes parfois incompris sont ici réunis : le rappeur Disiz (41 ans) et le footballeur Hatem Ben Arfa (32 ans). Les deux hommes ont percé, brillé très jeune mais leur carrière est, depuis, tout sauf linéaire. Rencontre avec deux créatifs, touchants de sincérité.
#
#
#     Voilà quatre saisons de suite que les phases finales se refusent à eux. Cette année, les Parisiens avaient pourtant l'argent, des recrues de poids et un coach à la stature internationale. Alors, que s'est-il passé ?
#
#
#     Sa saison a pris fin dès le premier tour des play-offs par la faute de James Harden et de Houston. Rudy Gobert, de passage en France, s'est confié à Step back. Son appétit avec Utah comme avec les Bleus est-il intact ?
#
#
#
#
#
#
#     Abandonné par un faux agent en 2015, le jeune footballeur ivoirien Marc-Olivier Glazaï, 18 ans, avait réussi à s'insérer au Stade Brestois. Il est aujourd'hui frappé d'une obligation de quitter le territoire français, et soutenu par le club.
#
#
#     L'art de glisser est une composante essentielle du jeu et du spectacle sur terre battue. Certains joueurs le pratiquent instinctivement. D'autres y sont complètement réfractaires.
#
#
#     Capitaine de Coupe Davis de 1954 à 1965, Benjamin Berthet, dit Benny, a été adulé par ceux qui ont joué sous ses ordres. Mais son fait de gloire remonte à la Seconde Guerre mondiale. De confession juive, il a remporté le tournoi de sa vie derrière les barbelés d'un camp en Allemagne.
#
#
#     Maudit depuis près de soixante-dix ans, le maillot blanc de la Seleçao resurgit le mois prochain lors de la Copa America. Avec l'espoir qu'il soit moins politisé que la célèbre tunique jaune
#
#
#
#
#     Découvrez le onzième épisode de « Varatata », le programme de pastilles humoristiques autour du VAR de L'Équipe et Football Total.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     L'alpiniste Élisabeth Revol a atteint le sommet de l'Everest sans oxygène ce jeudi, le plus haut de la planète (8 848 m), en Himalaya. Elle serait la première Française à réussir cet exploit.
#
#
#     Le FC Nantes vient de dévoiler son maillot domicile pour la saison 2019-2020. Une tunique, très critiquée par les supporters du club, que les Canaris porteront lors du match face au RC Strasbourg, vendredi soir (21h05).
#
#
#     Inspiré par diverses disciplines sportives, comme l'haltérophilie, la gymnastique et la musculation, le CrossFit vise la santé optimale. Un franc succès en France depuis 7 ans, il a néanmoins été controversé pour des risques de blessures au vu de l'intensité des exercices.
#
#
#     Awet Gebremedhin a fui l'Érythrée et a vécu clandestinement en Suède dans le seul but de devenir un jour coureur professionnel. Il porte aujourd'hui le maillot d'Israël Cycling Academy.

# %% [markdown]
# ### Scrapping en live via une requete HTTP

# %% [markdown]
# HTTP est un espèce de langage qui va permettre au client (vous, par le biais de votre navigateur par exemple) de communiquer avec un serveur connecté au réseau (le serveur HTTP installé sur le serveur d'un site, par exemple Apache).
#
# Les requêtes vont toujours par paires : la demande (du client) et la réponse (du serveur).
# Si ce n'est pas le cas, c'est qu'un problème est survenu à un endroit du réseau.
#
# La syntaxe de la demande (= requête client) est toujours la même :
# - Ligne de commande (Commande, URL, Version de protocole)

# %% [markdown]
# Commande est la méthode à utiliser, il spécifie le type de requête, il peut avoir les valeurs :
#
#
# GET
# C'est la méthode la plus courante pour demander une ressource. Une requête GET est sans effet sur la ressource, il doit être possible de répéter la requête sans effet.
#
# HEAD
# Cette méthode ne demande que des informations sur la ressource, sans demander la ressource elle-même.
#
# POST
# Cette méthode doit être utilisée lorsqu'une requête modifie la ressource.
#
# OPTIONS
# Cette méthode permet d'obtenir les options de communication d'une ressource ou du serveur en général.
#
# CONNECT
# Cette méthode permet d'utiliser un proxy comme un tunnel de communication.
#
# TRACE
# Cette méthode demande au serveur de retourner ce qu'il a reçu, dans le but de tester et d'effectuer un diagnostic sur la connexion.
#
# PUT
# Cette méthode permet d'ajouter une ressource sur le serveur.
#
# DELETE
# Cette méthode permet de supprimer une ressource du serveur.
#
# Je n'aborderai ici que les plus courantes : HEAD, GET et POST.

# %% [markdown]
# ### Concretement

# %%
import requests
# L'url du site à scrapper
url='https://www.lequipe.fr/'
# J'emet ma requet HTTP avec un"GET" au serveur du site identifier dans l'url
r = requests.get(url)
# J'affiche l'url requété ainsi que le retour du serveur
print(url, r.status_code)
# Je demande à beautifulSoup de conserver dans une variable soup la page web à scrapper (url) un script html
soup = BeautifulSoup(r.content,'html')
soup
# Out:
# https://www.lequipe.fr/ 200
# <!DOCTYPE html>
# <html class="" tpl="v7/home">
# <head>
# <!-- IDS : 3 -->
# <!-- TYPEPAGE : home_rub -->
# <!-- TAG_EDITO_LIB : general -->
# <!-- www.lequipe.fr -->
# <script type="text/javascript">
#
# 				codeweb = 'WTF';
# 				idtag = '1';
# 				sas_pageid='2368/17155';
#
#
# 				xtn2 = "23"; /* (General) */
# 				xtpage = "General::home";
#
# 				</script>
# <script>
#                 var xtpage = 'General::home';
#             </script>
# <meta content="300" http-equiv="refresh"/>
# <script>
#                     sas_formatids = "2077,2078,2163,630,12340,632,1075,1446,651,646,17532";
#                 </script>
# <script>
#                     var at_typePage = "home";
#                 </script>
# <script>
#     var urlBetaLequipe = 'beta.lequipe.fr';
#     var currentUrl = document.location.href;
#     if (document.cookie.indexOf('betatester') > -1 && (currentUrl.indexOf("www.lequipe") > -1 || currentUrl.indexOf("abonnes.lequipe") > -1)) {
#         document.location.href = currentUrl.replace('www.lequipe.fr', urlBetaLequipe).replace('abonnes.lequipe.fr', urlBetaLequipe)
#     }
# </script>
# <meta charset="utf-8"/>
# <title>L'ÉQUIPE - L'actualité du sport en continu.</title>
# <meta content="Le sport en direct sur L'EQUIPE.fr. Les informations, résultats et classements de tous les sports. Directs commentés, images et vidéos à regarder et à partager !" name="Description"/>
# <meta content="7" property="version:efr"/>
# <meta content="https://www.lequipe.fr/" itemprop="url"/>
# <meta content="/v7-lequipe/shared/generated/includes/" itemprop="dynamic"/>
# <meta content="42ztUq_6M1oIgM8mQ5XOzhmpA_LqDFmInnBEc2gGYY4" name="google-site-verification"/>
# <!-- pas abo -->
# <!-- pas domaine beta -->
# <script src="/elements/js/standalone/detectmobiles.js?2017" type="text/javascript"></script>
# <link href="https://www.lequipe.fr/" rel="dns-prefetch"/>
# <link as="script" href="https://xe2jlmuyam.kameleoon.eu/kameleoon.js" rel="preload"/>
# <script src="/common/js/external/kameleoon.js" type="text/javascript"></script>
# <!-- BEGIN Krux Control Tag for "AMA_LEquipe" -->
# <!-- Source: /snippet/controltag?confid=JJ8luyXM&site=AMA_LEquipe&edit=1 -->
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#         if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#         n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t,s)}(window, document,'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '125278988146629');
#     fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=125278988146629&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <meta content="activity_sport" name="object_type"/>
# <!-- "/"  -->
# <script>
#     if(window.location.host.indexOf('gcp')!==-1 || window.location.host.indexOf('chaine')!==-1 || window.location.host.indexOf('abonnes')!==-1 ) {
#         document.write('<meta name="robots" content="noindex">');
#     }
# </script>
# <link href="https://www.lequipe.fr/" rel="canonical"/>
# <link href="https://m.lequipe.fr/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta content="L'ÉQUIPE" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="fr_FR" property="og:locale"/>
# <meta content="L'ÉQUIPE - L'actualité du sport en continu." property="og:title"/>
# <meta content="Le sport en direct sur L'EQUIPE.fr. Les informations, résultats et classements de tous les sports. Directs commentés, images et vidéos à regarder et à partager !." property="og:description"/>
# <meta content="https://www.lequipe.fr/" property="og:url"/>
# <meta content="//www.lequipe.fr/elements/svg/logo-lequipe.svg" property="og:image"/>
# <meta content="L'ÉQUIPE - L'actualité du sport en continu." name="twitter:title"/>
# <meta content="Le sport en direct sur L'EQUIPE.fr. Les informations, résultats et classements de tous les sports. Directs commentés, images et vidéos à regarder et à partager !" name="twitter:description"/>
# <meta content="https://www.lequipe.fr/" name="twitter:url"/>
# <meta content="//www.lequipe.fr/elements/svg/logo-lequipe.svg" name="twitter:image"/>
# <meta content="261959740493169" property="fb:app_id"/>
# <meta content="607767138" property="fb:admins"/>
# <meta content="682217508" property="fb:admins"/>
# <meta content="18936161" property="twitter:account_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@lequipe" name="twitter:site"/>
# <meta content="76283417065" property="fb:pages"/>
# <link href="/elements/img/favicons/apple-touch-icon-57x57.png?140917" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/elements/img/favicons/apple-touch-icon-60x60.png?140917" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/elements/img/favicons/apple-touch-icon-72x72.png?140917" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/elements/img/favicons/apple-touch-icon-76x76.png?140917" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/elements/img/favicons/apple-touch-icon-114x114.png?140917" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/elements/img/favicons/apple-touch-icon-120x120.png?140917" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/elements/img/favicons/apple-touch-icon-144x144.png?140917" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/elements/img/favicons/apple-touch-icon-152x152.png?140917" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/elements/img/favicons/apple-touch-icon-180x180.png?140917" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/elements/img/favicons/favicon-32x32.png?140917" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/elements/img/favicons/android-chrome-192x192.png?140917" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/elements/img/favicons/favicon-96x96.png?140917" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/elements/img/favicons/favicon-16x16.png?140917" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/elements/img/favicons/manifest.json" rel="manifest"/>
# <link href="//www.lequipe.fr/elements/img/favicons/apple-touch-icon-16x16.png" rel="icon" type="image/x-icon"/>
# <meta content="#ed1c24" name="msapplication-TileColor"/>
# <meta content="/elements/img/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ed1c24" name="theme-color"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/elements/css/style-cch-20190523145742.min.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 9]>
#     <link href="/elements/css/ie-cch-20190523145742.min.css" rel="stylesheet" type="text/css" />
# <![endif]-->
# <!--[if (gte IE 6)&(lte IE 8)]>
#     <script src="/elements/js/plugins/selectivizr-min.js"></script>
# <![endif]-->
# <script type="text/javascript">
#   var features = {};
#       features.timeIso = "2019-05-26T13:14:14+0000";
#       features.blockBuying = "1";
#       features.incitativePopin = "1";
#       features.feed = "//iphdata.lequipe.fr/iPhoneDatas/EFR/STD/ALL/";
# </script>
# <script>  porte_ouverte_mpp=0;</script>
# <script>
#     var VEL;
#     var sas_target;
#     var popin;
# </script>
# <script>
#    var idSport="3";
# </script>
# <script src="//cdn.tagcommander.com/4284/tc_LEQUIPE_21.js" type="text/javascript"></script>
# <script type="text/javascript">
#         var __cmp = __cmp || null
#         function setCmpOptout(answer = true) {
#             localStorage.setItem("cmpOptout", JSON.stringify(answer));
#         }
#         if (__cmp && !getCookie('cmpLequipe')) {
#             setTimeout(function() {
#                 __cmp('getVendorConsents', null, function(result, success) {
#                     var purposeConsent = Object.values(result.purposeConsents);
#                     var hasConsent = true;
#                     for (var i = 0; i < purposeConsent.length; i++) {
#                         if (!purposeConsent[i]) {
#                             hasConsent = false;
#                             break;
#                         }
#                     }
#                     setCmpOptout(hasConsent);
#                     createCookie('cmpLequipe', '1', 1000);
#                 });
#             }, 5000);
#
#             document.addEventListener('scroll', function(e) {
#                 if (getCookie('cmpLequipeAction') === "") {
#                     createCookie('cmpLequipeAction', '1', 1000);
#                     setCmpOptout(true);
#                 }
#             });
#             document.addEventListener('click', function(e) {
#                 if (getCookie('cmpLequipeAction') === "") {
#                     createCookie('cmpLequipeAction', '1', 1000);
#                     setCmpOptout(true);
#                 }
#             });
#         }
#     </script>
# <script>
#         if (typeof(sas_target)=="undefined") {
#             sas_target="lequipe";
#         }
#     </script>
# <script src="/elements/js/0CA20190526124201ADs201905261242014F98d8q4aBxcs.js"></script>
# <script type="text/javascript">
#     var gs_result = "";
#     var parseResponse = function(result) {
#         gs_result = result;
#     };
#     var gsurl = window.location != window.top.location ? document.referrer : window.location;
#     var scriptElt1 = document.createElement("script");
#     scriptElt1.id = "tc_script_999_1";
#     scriptElt1.type = "text/javascript";
#     scriptElt1.src = "//laplace.grapeshot.co.uk/main/channels-jsonp.cgi?url=" + encodeURIComponent(gsurl) + "&callback=parseResponse";
#     scriptElt1.async = true;
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0] || document.getElementsByTagName('script')[0].parentNode).insertBefore(scriptElt1, null);
# </script>
# <script>var hasAutoplay = true;</script>
# <script>
#             var cmpOptout = false;
#             switch(localStorage.getItem('cmpOptout')) {
#               case 'true' :  cmpOptout = true; break;
#               case 'false' : cmpOptout = false; break;
#               default :  cmpOptout = false; break;
#             }
#     </script>
# <script async="" src="/elements/js/standalone/prebid_lequipe-cch-20190523145742.js" type="text/javascript"></script>
# <script>
#         /* Nugg.ad - v2 - 201601025 */
#         var nuggtg = encodeURIComponent('sport');
#         var nuggrid = encodeURIComponent(top.location.href);
#         var nuggscr = document.createElement('script');
#         nuggscr.type = 'text/javascript';
#         nuggscr.src ='//lpm-amaury.nuggad.net/rc?nuggn=1218387167&nuggsid=977061605&nuggtg='+nuggtg+'&nuggrid='+nuggrid+'';
#         var n = document.getElementsByTagName('script')[0];
#         n.parentNode.insertBefore(nuggscr, n);
#         /* Fin Nugg.ad */
#     </script>
# <script type="text/javascript">
#         bw_ps_adspot_id = "12374016";
#         if(localStorage) {ps_version = localStorage.getItem('ps_version');}
#         if(typeof ps_version =='undefined' || ps_version == null) {ps_version = new Date().getTime();}
#         document.write('<scr'+'ipt src="https://abs.proxistore.com/abe/js/psuniversaltag.js?v='+ps_version+'" type="text/javascript" async></scr'+'ipt>');
#     </script>
# <script type="text/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function() {
#             var gads = document.createElement("script");
#             gads.async = true;
#             gads.type = "text/javascript";
#             var useSSL = "https:" == document.location.protocol;
#             gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#             var node =document.getElementsByTagName("script")[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#     </script>
# <script src="/elements/js/standalone/ads-cch-20190523145742.js" type="text/javascript"></script>
# <link href="/elements/css/standalone/widget.css?20190523145742" rel="stylesheet"/>
# </head>
# <body ac="" an="" class="ev7 page-home js-home-page " sport="General" type="home_rub">
# <div class="ads DFP DFP--dfp_interstitiel v2 js-ads js-ad--dfp_interstitiel" id="dfp_interstitiel">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_interstitiel"); });
#                 </script>
# </div>
# <div class="navigation js-navigation ">
# <div class="navigation__toplinks">
# <a href="//www.lequipe.fr">L'Équipe</a>
# <a href="//www.lequipe.fr/Adrenaline/">Adrénaline</a>
# <a href="//www.lequipe.fr/Coaching/">L'Équipe coaching</a>
# <a href="//www.lequipe.fr/Sport-et-style/">Sport&amp;Style</a>
# <a href="//www.lequipe.fr/Velo-mag/">Vélo magazine</a>
# <a href="http://roustantv.lequipe.fr/">Roustan TV</a>
# </div>
# <div class="navigation__home">
# <div class="navigation__home__universe">
# <a class="le-journal" href="/abonnement/kiosque/" title="le journal L'Equipe"></a>
# <a class="la-chaine" href="/lachainelequipe/" title="la chaîne L'Equipe"><span></span></a>
# </div>
# <div class="navigation__logo logo logo--lequipe"><a href="/"></a></div>
# <div class="navigation__home__abopremium js-ctaLanding">
# <a href="//www.lequipe.fr/abonnement/offres/14701?prov=W-HP-BHHPG" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'105',format:'[W-HP-BHHPG]'}});">
# <img alt="Promo Premium" src="/elements/img/premium/bloc_abonnement_oreillette--14767.png"/>
# <div class="navigation__home__abopremium--texte">
# <span>abonnez-vous</span>
# <span>sans engagement</span>
# <span class="grey">1€ pendant 1 mois</span>
# </div>
# </a>
# </div>
# </div>
# <div class="navigation__menu">
# <div class="navigation__menu__home">
# <ul>
# <li>
# <a class="icon icon--house icon--black" href="/" title="L'Equipe"></a>
# </li>
# <li class="Premium onglet-premium ">
# <a class="textLink" href="https://abonnes.lequipe.fr/#decouverte">abonné</a>
# </li>
# <li class="Football"> <a class="textLink" href="/Football/">            Football   </a> </li> <li class="Rugby"> <a class="textLink" href="/Rugby/">            Rugby   </a> </li> <li class="Tennis"> <a class="textLink" href="/Tennis/Roland-garros/">            Tennis   </a> </li> <li class="Cyclisme"> <a class="textLink" href="/Cyclisme/Cyclisme-sur-route/Tour-d-italie/">            Cyclisme   </a> </li> <li class="Basket"> <a class="textLink" href="/Basket/">            Basket   </a> </li> <li class="Formule1"> <a class="textLink" href="/Formule-1/">            F1   </a> </li> <li class="Handball"> <a class="textLink" href="/Handball/">            Handball   </a> </li> <li class="Golf"> <a class="textLink" href="/Golf/">            Golf   </a> </li> <li class="Ski-Glace"> <a class="textLink" href="/Aussi/Ski-glace/">            Ski-Glace   </a> </li> <li class="Basket"> <a class="textLink" href="/Basket/Nba/">            NBA   </a> </li> <li class="Athletisme"> <a class="textLink" href="/Athletisme/">            Athlé   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Volley-ball/">            Volley   </a> </li> <li class="Sports-us"> <a class="textLink" href="/Sports-us/">            Sports US   </a> </li> <li class="Auto-moto"> <a class="textLink" href="/Auto-moto/">            Auto-moto   </a> </li> <li class="Voile"> <a class="textLink" href="/Voile/">            Voile   </a> </li> <li class="Natation"> <a class="textLink" href="/Natation/">            Natation   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Biathlon/">            Biathlon   </a> </li> <li class="Adrenaline"> <a class="textLink" href="/Adrenaline/">            Adrénaline   </a> </li> <li class="Aussi"> <a class="textLink" href="/Adrenaline/Surf/World-surf-league/">            WSL   </a> </li> <li class="Coaching"> <a class="textLink" href="/Coaching/">            Coaching   </a> </li> <li class="Sport-et-style"> <a class="textLink" href="/Sport-et-style/">            Sport &amp; Style   </a> </li> <li class="Velo-mag"> <a class="textLink" href="/Velo-mag/">            Vélo Magazine   </a> </li> <li class="Tennis"> <a class="textLink" href="/Tennis/Roland-garros/">            Roland-Garros   </a> </li> <li class="Football"> <a class="textLink" href="/Football/Ligue-des-champions/">            Ligue des champions   </a> </li> <li class="Cyclisme"> <a class="textLink" href="/Cyclisme/Cyclisme-sur-route/Tour-d-italie/">            Giro 2019   </a> </li>
# <li class="Adrenaline"><a href="/Adrenaline/">adrénaline</a></li>
# <li class="Ilosport"><a href="/Coaching/">coaching</a></li>
# <li class="menu__plus"><a class=" js-menu-plus">...</a></li>
# </ul>
# </div>
# <div class="navigation__menu__directres js-directs-resultats">
# <a class="navigation__menu__directres__directs" href="/Directs">
# <span class=" skew skew--red skew--left navigation__menu__directres__directs__title">
#                 directs
#         </span>
# <style>
#             .navigation__menu__directres__directs__nbdirects:before {
#                 display: inline-block;
#                 content: "12";
#                 transform: initial;
#                 padding-left: 0px;
#                 position: relative;
#                 z-index: 1;
#             }
#         </style>
# <span class=" skew skew--red skew--right navigation__menu__directres__directs__nbdirects"></span>
# </a>
# <a class="navigation__menu__directres__resultats" href="/Resultats">
# 		résultats
# 	</a>
# <a class="navigation__menu__directres__agenda" href="/programme-tv/agenda.html">
#             programme TV
#         </a>
# <a class="navigation__menu__directres__videos" href="//video.lequipe.fr">
#             vidéos
#         </a>
# <a class="navigation__menu__directres__videos navigation__menu__directres__videos--green js-discover-beta" href="//beta.lequipe.fr">
#             nouveau site
#         </a>
# </div>
# <div class="navigation__menu__compte-search">
# <div class="navigation__menu__menuright"><a class="icon icon--user icon--black js-account-user">
# <img class="picture-user js-picture-user" src="#"/>
# </a>
# </div>
# <div class="navigation__menu__menuright"><a class="icon icon--burger icon--black js-menu-burger"></a>
# </div>
# </div>
# </div>
# <div class="navigation__menu navigation__menu--sticky">
# <div>
# <div>
# <a class="icon icon--house icon--black" href="/" title="L'Equipe"></a>
# </div>
# <div class="navigation__menu__logo">
# <div class="navigation__logo logo logo--lequipe"><a href="/"></a></div>
# </div>
# <a class="navigation__menu__sport js-libNavSport" href="#"> </a>
# <div class="navigation__menu__plus js-menu-plus">...</div>
# </div>
# <div>
# <div>
# <div class="navigation__menu__directres js-directs-resultats">
# <a class="navigation__menu__directres__directs" href="/Directs">
# <span class=" skew skew--red skew--left navigation__menu__directres__directs__title">
#                 directs
#         </span>
# <style>
#             .navigation__menu__directres__directs__nbdirects:before {
#                 display: inline-block;
#                 content: "12";
#                 transform: initial;
#                 padding-left: 0px;
#                 position: relative;
#                 z-index: 1;
#             }
#         </style>
# <span class=" skew skew--red skew--right navigation__menu__directres__directs__nbdirects"></span>
# </a>
# <a class="navigation__menu__directres__resultats" href="/Resultats">
# 		résultats
# 	</a>
# <a class="navigation__menu__directres__agenda" href="/programme-tv/agenda.html">
#             programme TV
#         </a>
# <a class="navigation__menu__directres__videos" href="//video.lequipe.fr">
#             vidéos
#         </a>
# <a class="navigation__menu__directres__videos navigation__menu__directres__videos--green js-discover-beta" href="//beta.lequipe.fr">
#             nouveau site
#         </a>
# </div>
# </div>
# <div class="navigation__menu__compte-search">
# <div class="navigation__menu__menuright">
# <a class="Premium onglet-premium textLink" href="/abonnement/offres/14701?prov=W-THP-STKY" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'108',format:'[W-THP-STKY]'}});">s'abonner</a>
# </div>
# <div class="navigation__menu__menuright">
# <a class="icon icon--user icon--black js-account-user">
# <img class="picture-user js-picture-user" src="#"/>
# </a>
# </div>
# <div class="navigation__menu__menuright">
# <!-- Error occurred -->
# </div>
# <div class="navigation__menu__menuright">
# <a class="icon icon--burger icon--black js-menu-burger"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- OUTER EDITO CONTENT -->
# <div class="container" id="outer-edito-content">
# <div class="home container__use js-content">
# <div class="ads DFP DFP--dfp_banniere-haute v2 js-ads js-ad--dfp_banniere-haute" id="dfp_banniere-haute">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_banniere-haute"); });
#                 </script>
# </div>
# <div data-iab-tag="dfp_banniere_haute"></div>
# <section class="row row--first oreillettes" data-vr-zone="LiensImages">
# <div class="oreillettes__item col " data-vr-contentbox="" rub="Football" sport="36" type="OREILLETTE">
# <a date="" double="0" href="/Football/Directs" onglet="1" quadruple="0" target="_blank" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/oreillette-v6-5-foot/1500000000288539/0:0,150:90-120-90-75/1ce06.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Foot</div>
# <div class="oreillettes__label">Les matches</div>
# <span class="skew skew--right skew--red">direct</span>
# </div>
# </a>
# </div><div class="oreillettes__item col " data-vr-contentbox="" rub="Tennis" sport="39" type="OREILLETTE">
# <a date="" double="0" href="/Tennis/Directs" onglet="1" quadruple="0" target="_blank" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/-/1500000001157427/82:0,2221:1604-120-90-75/51530.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Roland-Garros</div>
# <div class="oreillettes__label">les matches</div>
# <span class="skew skew--right skew--red">direct</span>
# </div>
# </a>
# </div><div class="oreillettes__item col " data-vr-contentbox="" rub="vide" sport="vide" type="OREILLETTE">
# <a date="" double="0" href="/en-direct/roland-garros-2019-en-direct/404" onglet="0" quadruple="0" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/-/1500000001157428/200:171,2096:1593-120-90-75/c7c3d.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Roland-Garros</div>
# <div class="oreillettes__label">l'actu</div>
# <span class="skew skew--right skew--red">direct</span>
# </div>
# </a>
# </div><div class="oreillettes__item col " data-vr-contentbox="" rub="Cyclisme" sport="38" type="OREILLETTE">
# <a date="" double="0" href="/Cyclisme/course/15193/saint-vincent-courmayeur" onglet="1" quadruple="0" target="_blank" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/giro-2019-emission/1500000001149999/0-120-90-75/b6782.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Giro</div>
# <div class="oreillettes__label"></div>
# <span class="skew skew--right skew--red">direct</span>
# </div>
# </a>
# </div>
# </section>
# <div class="row">
# </div>
# <div class="row">
# <div class="col col--x2" data-vr-zone="Actualites">
# <div class="home__lead " data-vr-zone="TitrePrincipal" rub="Football" sport="36" type="UNEGDLEADER">
# <div data-vr-contentbox="">
# <h1 class="home__lead__title title title--sm">
# <a href="/Tennis/Roland-garros/2019-premier-tour-direct-lorenzo-sonego-roger-federer-live/258773">Federer, le grand retour</a>
# </h1>
# <a class="home__lead__image" href="/Tennis/Roland-garros/2019-premier-tour-direct-lorenzo-sonego-roger-federer-live/258773" target="_blank">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Roland-Garros                </div>
# <div class="tags__element skew skew--darkgrey">
#                         1er tour (H)
#                     </div>
# </div>
# <img alt="Federer, le grand retour" src="https://medias.lequipe.fr/img-photo-jpg/-/1500000001157566/0-624-416-75/cfa38.jpg"/>
# </a>
# <a href="/Tennis/Roland-garros/2019-premier-tour-direct-lorenzo-sonego-roger-federer-live/258773">
# <p class="home__lead__details">
# </p></a>
# <div class="home__lead__links">
# <a class="home__colead__links__element" href="/Tennis/TennisTableauTournoi8240.html">
#                 Tableau (H)
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/Actualites/Roger-federer-a-propos-de-sa-victoire-a-roland-garros-en-2009-apres-l-elimination-de-nadal-il-fallait-gagner/1022359">
#                 Federer : «En 2009, il fallait gagner»
#                             </a>
# </div>
# </div>
# </div>
# <div class="ads DFP DFP--dfp_banniere-flux-autopromo v2 js-ads js-ad--dfp_banniere-flux-autopromo" id="dfp_banniere-flux-autopromo">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_banniere-flux-autopromo"); });
#                 </script>
# </div>
# <div class="home__colead " data-vr-contentbox="" rub="Formule1" sport="102">
# <a class="home__colead" href="/Formule-1/direct-grand-prix-gp-de-monaco-2019-live/1110" target="_blank">
# <div class="home__colead__image ">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     F1                </div>
# <div class="tags__element skew skew--darkgrey">
#                         GP de Monaco
#                     </div>
# <div class="tags__element skew skew--red ">
#                 direct
#             </div>
# </div>
# <img alt="Qui peut contrarier Mercedes ?" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/hamilton-lewis-gbr/1500000001157558/554:650,2075:1664-624-416-75/51a23.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <div class="home__colead__image__embed">
# <h2 class="home__colead__title title title--xs">
#
#             Qui peut contrarier Mercedes ?
#
# </h2><p class="home__colead__details">
# </p> </div>
# </div>
# </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Formule-1/f1-classement-pilotes.html">
#                 Classement des pilotes
#                             </a>
# <a class="home__colead__links__element" href="/Formule-1/f1-calendrier.html">
#                 Calendrier de la saison
#                             </a>
# </div>
# </div>
# <script>
#             var ctaNameId = '';
#             typeof atnameID != 'undefined' ? ctaNameId = '_' + atnameID : ctaNameId = '';
#         </script>
# <div class="offer js-ctaLanding">
# <div class="offer__bloc">
# <h2 class="offer__title">
# </h2><p class="offer__highlight">1€</p>
#                         pendant 1 mois*
#
#
#
#
#                 <p class="offer__details">puis 9,99€/mois sans engagement</p>
# <a class="button button--big button--yellow" href="//www.lequipe.fr/abonnement/offres/14701?prov=W-HP-LBAN&amp;returnurl=/" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'104',format:'[W-HP-LBAN'+ctaNameId+']'}});">j'en profite</a>
# <p class="offer__mentions">
#
#                         * voir conditions
#
#                 </p>
# </div>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Actualites/Brest-choisit-finalement-dall-oglio-pour-succeder-a-furlan/1022924">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Foot                </div>
# <div class="tags__element skew skew--darkgrey">
#                         L1
#                     </div>
# </div>
# <img alt="Brest choisit finalement Dall'Oglio" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/olivier-dall-oglio-etait-la-priorite-des-dirigeants-brestois-a-martin-l-equipe/1500000001157489/0:0,1997:1331-304-202-75/ed7d2.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Actualites/Brest-choisit-finalement-dall-oglio-pour-succeder-a-furlan/1022924">
# <h2 class="home__colead__title title title--xxs">
#
#             Brest choisit finalement Dall'Oglio
#
# </h2><p class="home__colead__details">
#     Le Stade Brestois, de retour en L1, sera entraîné par Olivier Dall'Oglio la saison prochaine même si, ces derniers jours, Christophe Pelissier semblait tenir la corde.
# </p> </a>
# </div> </div>
# <div class="ads DFP DFP--dfp_banniere-flux-1 v2 js-ads js-ad--dfp_banniere-flux-1" id="dfp_banniere-flux-1">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_banniere-flux-1"); });
#                 </script>
# </div>
# <div class="folder tennis" data-vr-zone="Dossier-Tennis" rub="Tennis" sport="39" type="DOSSIER">
# <div class="tags">
# <div class="tags__element tags__element--lg skew skew--right " jquery="text" json="titresport">Roland-Garros</div>
# </div>
# <div class="colsort">
# <div class="home__colead " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead" href="/Tennis/Roland-garros/2019-premier-tour-direct-marco-cecchinato-nicolas-mahut-live/258766" target="_blank">
# <div class="home__colead__image ">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         1e tour (H)                    </div>
# <div class="tags__element skew skew--red ">
#                 direct
#             </div>
# </div>
# <img alt="Mahut, ça se complique" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/-/1500000001157548/0-624-416-75/465f0.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <div class="home__colead__image__embed">
# <h2 class="home__colead__title title title--xs">
#
#             Mahut, ça se complique
#
# </h2><p class="home__colead__details">
# </p> </div>
# </div>
# </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Tennis/Directs" target="_blank">
#                 Tous les matches en direct
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/SH_RG.html">
#                 Tableau (H)
#                             </a>
# </div>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Tennis" sport="39">
# <a class="home__colead__image" href="/Tennis/Directs" target="_blank">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--red skew--right">
#                 direct
#             </div>
# </div>
# <img alt="Tous les matches en direct" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/tennis-french-open-roland-garros-paris-france-may-26-2019-france-s-quentin-halys-in-action/1500000001157552/0-304-202-75/ace04.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Tennis/Directs" target="_blank">
# <h2 class="home__colead__title title title--xxs">
#
#             Tous les matches en direct
#
# </h2><p class="home__colead__details">
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Tennis/SH_RG.html">
#                 Tableau (H)
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/SD_RG.html">
#                 Tableau (F)
#                             </a>
# </div>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/en-direct/roland-garros-2019-en-direct/404" target="_blank">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--red skew--right">
#                 direct
#             </div>
# </div>
# <img alt="C'est déjà fini pour Kerber" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/kerber-angelique-ger/1500000001157521/0:165,1665:1275-304-202-75/1c63e.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/en-direct/roland-garros-2019-en-direct/404" target="_blank">
# <h2 class="home__colead__title title title--xxs">
#
#             C'est déjà fini pour Kerber
#
# </h2><p class="home__colead__details">
#     Retrouvez ici toutes les informations du jour.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Tennis/SH_RG.html">
#                 Tableau (H)
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/SD_RG.html">
#                 Tableau (F)
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/Actualites/Roland-garros-garbine-muguruza-lache-un-set-mais-file-au-deuxieme-tour/1022929">
#                 Muguruza lâche un set
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/Actualites/Angelique-kerber-eliminee-par-anastasia-potapova-au-premier-tour/1022921">
#                 Kerber éliminée d'entrée
#                             </a>
# </div>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Tennis" sport="39">
# <a class="home__colead__image" href="/Tennis/Actualites/Roland-garros-felix-auger-aliassime-declare-forfait/1022943">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Tableau (H)                </div>
# </div>
# <img alt="Auger-Aliassime déclare forfait" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/pas-de-roland-garros-pour-felix-auger-aliassime-b-cremel-l-equipe/1500000001157563/0:0,1994:1330-304-202-75/f3e53.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Tennis/Actualites/Roland-garros-felix-auger-aliassime-declare-forfait/1022943">
# <h2 class="home__colead__title title title--xxs">
#
#             Auger-Aliassime déclare forfait
#
# </h2><p class="home__colead__details">
#     Touché aux adducteurs, le Canadien Félix Auger-Aliassime a déclaré forfait pour Roland-Garros.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Tennis/Actualites/Tournoi-atp-de-lyon-benoit-paire-s-impose-en-finale-face-a-felix-auger-aliassime/1022645">
#                 Paire titré à Lyon face à Auger-Aliassime
#                             </a>
# </div>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Tennis" sport="39">
# <a class="home__colead__image" href="/Tennis/Actualites/Roland-garros-stefanos-tsitsipas-accede-au-deuxieme-tour/1022942">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     1er tour (H)                </div>
# </div>
# <img alt="Tsitsipas sans souci" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/belle-entame-pour-stefanos-tsitsipas-reuters/1500000001157561/0:0,1968:1312-304-202-75/4fcf5.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Tennis/Actualites/Roland-garros-stefanos-tsitsipas-accede-au-deuxieme-tour/1022942">
# <h2 class="home__colead__title title title--xxs">
#
#             Tsitsipas sans souci
#
# </h2><p class="home__colead__details">
#     Pas de problème pour Stefanos Tsitsipas. Le Grec, tête de série n° 6, est facilement venu à bout de Maximilian Marterer (6-2, 6-2, 7-6 [4]). Il est au deuxième tour de Roland-Garros.
# </p> </a>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Tennis" sport="39">
# <a class="home__colead__image" href="/Tennis/Actualites/Roland-garros-ugo-humbert-battu-par-alexei-popyrin-au-premier-tour/1022935">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         1e tour (H)                    </div>
# </div>
# <img alt="Humbert n'a pas tenu" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/humbert-ugo-fra/1500000001157512/0-304-202-75/cfcb4.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Tennis/Actualites/Roland-garros-ugo-humbert-battu-par-alexei-popyrin-au-premier-tour/1022935">
# <h2 class="home__colead__title title title--xxs">
#
#             Humbert n'a pas tenu
#
# </h2><p class="home__colead__details">
#     Pour sa première apparition dans le tableau principal à Roland-Garros, le Français Ugo Humbert s'est incliné en quatre sets face à Alexei Popyrin.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Tennis/Roland-garros/2019-premier-tour-direct-alexei-popyrin-ugo-humbert-live/258776">
#                 Le film du match
#                             </a>
# <a class="home__colead__links__element" href="/Tennis/SH_RG.html">
#                 Tableau (H)
#                             </a>
# </div>
# </div> </div>
# <div class="home__colead videos uni" type="ACTUVIDEO">
# <h2 class="home__colead__title title title--light" jquery="attr.titre" json="titre" titre=""></h2>
# <div class="home__colead__videos" editmode="1" format="3d" jquery="attr.editmode;attr.format;attr.special" json="editmode;format;special" special="">
# <ul class="home__colead__videos__list">
# <li class="home__colead__video">
# <div class="home__colead__split home__colead__split-large" dmid="x799227" id_daily="x799227" id_media="1500000001156382" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre=": Federer «En 2009, il fallait gagner»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x799227" px-link="" px-provider="dailymotion" px-provider-id="x799227">
# <div class="tags">
# <div class="tags__element skew skew--right"></div>
# </div>
# <img alt=" -  Federer «En 2009, il fallait gagner»" src="//medias.lequipe.fr/img-video-cover/1500000001156382/490/275"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title title--micro"> Federer «En 2009, il fallait gagner»</h3>
# </div>
# <div class="home__colead__split multi">
# <div class="home__colead__multi" dmid="k7zJsiEhz5vuPCtHPU6" id_daily="x79cgre" id_media="1500000001157223" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre="Tennis - Roland-Garros : Les cinq Françaises en lice">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x79cgre" px-link="" px-provider="dailymotion" px-provider-id="k7zJsiEhz5vuPCtHPU6">
# <div class="tags">
# <div class="tags__element skew skew--right">Tennis - Roland-Garros </div>
# </div>
# <img alt="Tennis - Roland-Garros  -  Les cinq Françaises en lice" src="//medias.lequipe.fr/img-video-cover/1500000001157223/250/140"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title"> Les cinq Françaises en lice</h3>
# </div>
# <div class="home__colead__multi" dmid="k4xeq5kHZSo4dLtHPkk" id_daily="x79cf1s" id_media="1500000001157198" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre="Tennis - Roland-Garros : Les dix meilleurs Français en lice">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x79cf1s" px-link="" px-provider="dailymotion" px-provider-id="k4xeq5kHZSo4dLtHPkk">
# <div class="tags">
# <div class="tags__element skew skew--right">Tennis - Roland-Garros </div>
# </div>
# <img alt="Tennis - Roland-Garros  -  Les dix meilleurs Français en lice" src="//medias.lequipe.fr/img-video-cover/1500000001157198/250/140"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title"> Les dix meilleurs Français en lice</h3>
# </div>
# </div> </li>
# <li class="home__colead__video">
# <div class="home__colead__split home__colead__split-large" dmid="k1wBTrbWR1A2catHzov" id_daily="x79b3sj" id_media="1500000001156781" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre=": Mladenovic «Toujours très spécial de jouer ici»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x79b3sj" px-link="" px-provider="dailymotion" px-provider-id="k1wBTrbWR1A2catHzov">
# <div class="tags">
# <div class="tags__element skew skew--right"></div>
# </div>
# <img alt=" -  Mladenovic «Toujours très spécial de jouer ici»" src="//medias.lequipe.fr/img-video-cover/1500000001156781/490/275"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title title--micro"> Mladenovic «Toujours très spécial de jouer ici»</h3>
# </div>
# <div class="home__colead__split multi">
# <div class="home__colead__multi" dmid="x79btfy" id_daily="x79btfy" id_media="1500000001156915" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre="Tennis - ATP - Roland-Garros : Medvedev «Je me sens prêt»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x79btfy" px-link="" px-provider="dailymotion" px-provider-id="x79btfy">
# <div class="tags">
# <div class="tags__element skew skew--right">Tennis - ATP - Roland-Garros </div>
# </div>
# <img alt="Tennis - ATP - Roland-Garros  -  Medvedev «Je me sens prêt»" src="//medias.lequipe.fr/img-video-cover/1500000001156915/250/140"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title"> Medvedev «Je me sens prêt»</h3>
# </div>
# <div class="home__colead__multi" dmid="x799mqv" id_daily="x799mqv" id_media="1500000001156638" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre=": Djokovic «C'est là que je veux jouer mon meilleur tennis»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x799mqv" px-link="" px-provider="dailymotion" px-provider-id="x799mqv">
# <div class="tags">
# <div class="tags__element skew skew--right"></div>
# </div>
# <img alt=" -  Djokovic «C'est là que je veux jouer mon meilleur tennis»" src="//medias.lequipe.fr/img-video-cover/1500000001156638/250/140"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title"> Djokovic «C'est là que je veux jouer mon meilleur tennis»</h3>
# </div>
# </div> </li>
# <li class="home__colead__video">
# <div class="home__colead__split home__colead__split-large" dmid="k4kiLbFge2aHwatHa4P" id_daily="x7990p7" id_media="1500000001156357" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre=": Monfils «J'y crois vraiment»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x7990p7" px-link="" px-provider="dailymotion" px-provider-id="k4kiLbFge2aHwatHa4P">
# <div class="tags">
# <div class="tags__element skew skew--right"></div>
# </div>
# <img alt=" -  Monfils «J'y crois vraiment»" src="//medias.lequipe.fr/img-video-cover/1500000001156357/490/275"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title title--micro"> Monfils «J'y crois vraiment»</h3>
# </div>
# <div class="home__colead__split multi">
# <div class="home__colead__multi" dmid="k4o9XqWViQ1ZcItH7xC" id_daily="x798t6g" id_media="1500000001156271" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre=": Halep «J'ai juste envie de sourire»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x798t6g" px-link="" px-provider="dailymotion" px-provider-id="k4o9XqWViQ1ZcItH7xC">
# <div class="tags">
# <div class="tags__element skew skew--right"></div>
# </div>
# <img alt=" -  Halep «J'ai juste envie de sourire»" src="//medias.lequipe.fr/img-video-cover/1500000001156271/250/140"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title"> Halep «J'ai juste envie de sourire»</h3>
# </div>
# <div class="home__colead__multi" dmid="k7Mxo6gohOSyU6tH7Q0" id_daily="x798u24" id_media="1500000001156284" idmatch="" jquery="attr.sig;attr.dmid;attr.id_daily;attr.id_media;attr.sport;attr.titre" json="videos[].sig;videos[].dmid;videos[].id_daily;videos[].id_media;videos[].sport;videos[].titre" sig="200" sport="" titre=": Osaka «Je suis impatiente»">
# <a class="home__colead__image" href="//video.lequipe.fr/video/x798u24" px-link="" px-provider="dailymotion" px-provider-id="k7Mxo6gohOSyU6tH7Q0">
# <div class="tags">
# <div class="tags__element skew skew--right"></div>
# </div>
# <img alt=" -  Osaka «Je suis impatiente»" src="//medias.lequipe.fr/img-video-cover/1500000001156284/250/140"/>
# <span class="icon icon--video icon--big icon--square"></span>
# </a>
# <h3 class="home__colead__subtitle title"> Osaka «Je suis impatiente»</h3>
# </div>
# </div> </li>
# </ul>
# <div class="home__colead__paging">
# <a class="home__colead__paging__previous liprev" href="#" title="Précédent"></a>
# <div class="home__colead__paging__digits">
# <span class="page">1</span>/<span class="nbpage">3</span>
# </div>
# <a class="home__colead__paging__next linext" href="#" title="Suivant"></a>
# </div>
# </div>
# <a class="home__colead__button button button--white" href="//video.lequipe.fr">toutes les vidéos</a>
# </div>
# </div>
# <div class="home__colead">
# <a class="home__colead__button home__colead__button--folder button button--black" href="/Tennis/" jquery="text;attr.href" json="lienDos.texte;lienDos.href">toute l'actualité tennis  </a>
# </div>
# </div>
# <div class="home__colead " data-vr-contentbox="" rub="Rugby" sport="101">
# <a class="home__colead " href="/Rugby/match-direct/pro-d2/2018-2019/cab-bayonne-live/28963" target="_blank">
# <div class="home__colead__image">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Rugby                </div>
# <div class="tags__element skew skew--darkgrey">
#                         Top 14
#                     </div>
# <div class="tags__element skew skew--midgrey">
#                         Finale
#                     </div>
# <div class="tags__element skew skew--red ">
#                 direct
#             </div>
# </div>
# <img alt="Le Top 14 pour Brive ou Bayonne ?" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/laranjeira-thomas/1500000001157549/0-624-416-75/f8be4.jpg" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# </a>
# <!-- /base/rugby/bloc_match/963/28963.html" -->
# <a class="scoring" href="/Rugby/match-direct/pro-d2/2018-2019/cab-bayonne-live/28963">
# <div class="scoring__team">
# <img alt="Brive Logo" class="scoring__team__logo js-lazy" data-src="//medias.lequipe.fr/logo-rugby/8/30-alt-20190523145742" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <div class="scoring__team__name">Brive</div>
# </div>
# <div class="scoring__digits scoring__digits--live">
# <div class="scoring__digits__element scoring__digits__element--solo">direct</div>
# </div>
# <div class="scoring__team scoring__team__right">
# <div class="scoring__team__name">Bayonne</div>
# <img alt="Bayonne Logo" class="scoring__team__logo js-lazy" data-src="//medias.lequipe.fr/logo-rugby/97/30-alt-20190523145742" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# </a>
# <a href="/Rugby/match-direct/pro-d2/2018-2019/cab-bayonne-live/28963" target="_blank">
# <h2 class="home__colead__title title title--xs">
#
#             Le Top 14 pour Brive ou Bayonne ?
#
# </h2>
# <p class="home__colead__details">
# ...
# <div id="pictos-content">
# <a class="foo-compte" href="/mon-compte/">compte</a>
# <a class="foo-rss" href="/rss/">rss</a>
# <a class="foo-newsletter" href="/mon-compte/mes-newsletters" rel="nofollow">newsletter</a>
# <a class="foo-plan" href="/Fonctions/navs-plan-du-site.html">plan du site</a>
# <a class="foo-credits" href="/Fonctions/pages_credits.html" target="_blank">crédits</a>
# <a class="foo-cgu" href="/Fonctions/cgu.html">CGU</a>
# <a class="foo-mentions" href="/Fonctions/mentions-legales.html">mentions légales</a>
# <a class="foo-privacy" href="/Fonctions/politique-confidentialite.html">politique de confidentialité</a>
# <a class="foo-cookies" href="/cookies/">cookies</a>
# <a class="foo-contacts" href="/Fonctions/page_contacts.html">contacts</a>
# </div>
# </div>
# <div class="row row--colored baseline-content">
# <div class="amaury-content" id="amaury-content">
# <div>
# <a href="http://www.francefootball.fr/" rel="nofollow" target="_blank">FranceFootball</a> |
#             <a href="https://www.lequipe.fr/Adrenaline/" rel="nofollow" target="_blank">Adrénaline L'Équipe</a> |
#             <a href="https://www.lequipe.fr/Coaching/" rel="nofollow" target="_blank">L'Équipe Coaching</a> |
#             <a href="http://www.lequipemagazine.fr/" rel="nofollow" target="_blank">L'Équipe Magazine</a> |
#             <a href="https://www.lequipe.fr/Velo-mag/" rel="nofollow" target="_blank">Vélo Magazine</a> |
#             <a href="https://www.lequipe.fr/Sport-et-style/" rel="nofollow" target="_blank">Sport &amp; Style</a> |
#             <a href="http://www.aso.fr/" rel="nofollow" target="_blank">ASO</a> |
#             <a href="http://www.amaurymedias.fr/" rel="nofollow" target="_blank">Amaury Media</a> |
#             <a href="http://www.pressesports.com/" rel="nofollow" target="_blank">PresseSports</a> |
#             <a href="http://www.amaury.com/" rel="nofollow" target="_blank">Groupe Amaury</a> |
#             <a href="https://codepromo.lequipe.fr" target="_blank">Code promo</a> <span>© L'Equipe 24/24 -
#         2019
#         <br/>tous droits réservés</span>
# </div>
# </div>
# </div>
# </footer>
# <a class="backtotop js-backtotop"><span class="icon icon--medium icon--backtop"></span></a>
# <!--[if lt IE 9]>
#         <div class="oldie">
#     <div class="oldie__container">
#         <a href="#" class="icon icon--cross" onclick="document.getElementsByClassName('oldie')[0].parentNode.removeChild(document.getElementsByClassName('oldie')[0])"></a>
#         <p>
#             Vous utilisez une ancienne version d’Internet Explorer pour laquelle le site L'Équipe n’est plus optimisé.
#             <br/> Pour une utilisation optimale, merci de télécharger la dernière version d’IE en cliquant <a href="https://www.microsoft.com/fr-fr/download/internet-explorer.aspx">ici</a> ou d'utiliser Chrome ou Firefox.
#         </p>
#     </div>
# </div>
#     <![endif]-->
# </body>
# <script type="text/javascript">var popin=new Object();</script>
# <!-- SCRIPTS -->
# <script type="text/javascript">
# 	//sas_pageid = '(none)';
# 	//sas_target = '';
# 	//sas_blocked = false;
# </script>
# <div id="analyzer">
# <!-- DOCUMENT_URI == /v7-lequipe/dist/patterns/home.html -->
# <!-- REQUEST_URI == / -->
# <!-- tag_edito_lib == general -->
# <!-- code_web == WTF -->
# <script>
#                 atchapter1 = s17 = 'general';
#                 atchapter1 = s17 = atchapter1.toLowerCase().replace('elit1','top_14').replace('top14','top_14').replace('elit2','pro-d2').replace(/\-/g, "_");//.replace('d1','ligue-1').replace('d2','ligue-2')
#             </script>
# <div id="analyzer">
# <script>
#                 var at_docUri = '/v7-lequipe/dist/patterns/home.html';
#                 var at_repUrlUri = '/v7-lequipe/dist/patterns/home.html'.split('/')[3];
#                 var taggage = 'ON';
#             </script>
# </div>
# </div>
# <script src="/elements/js/scripts-cch-20190523145742.min.js"></script>
# <script async="">
#     (function createWeboramaPixel () {
#         var connectedInfosCookie = getCookie('lequipe-connected-infos');
#         var cryptedEmail = connectedInfosCookie ? JSON.parse(connectedInfosCookie).email_sha : '';
#         var pixel = document.createElement('img');
#         pixel.height = 1;
#         pixel.width = 1;
#         pixel.src = "https://redirect.frontend.weborama.fr/redirect/standard?url=https%3A%2F%2Fstags.bluekai.com%2Fsite%2F54472%3Flimit%3D1%26phint%3De_id_s%253D" +
#             cryptedEmail +
#             "%26phint%3Dusr_id%253D{WEBO_CID}​%26phint%3Dwebsite%253Dl_equipe";
#         document.body.appendChild(pixel);
#     })();
# </script>
# <!--[if lte IE 9]>
# <script>
#     $(document).ready(function(){
#         $('.js-content').css('margin-left', ($(window).width() - 960) / 2 -20);
#         $('.js-content').css('width', '960px');
#         $('.oreillettes,.oreillettes__item').remove();
#     });
# </script>
# <![endif]-->
# <!--[if lte IE 8]>
# <script>
#     $(document).ready(function(){
#         $('.logo--lequipe').css('background-image', 'url(/elements/img/ie/logo-lequipe.png)');
#         $('.navigation__menu--sticky').remove();
#
#         $('.navigation__menu__home').css('width','100%');
#         $('.navigation__menu__home ul li').css('margin','0 5px');
#         $('.navigation__menu__compte-search').remove();
#          $('.menu__plus').remove();
#
#
#
#
#        /*
#         $('.le-journal').addClass('ie-le-journal').removeClass('le-journal');
#         $('.la-chaine').addClass('ie-la-chaine').removeClass('la-chaine');
#         */
#     });
# </script>
# <![endif]-->
# <!-- BEGIN weborama -->
# <iframe src="//cstatic.weborama.fr/iframe/customers/premium.html?idEditeur=1176&amp;idSite=260" style="height:1px;width:1px;border:0 none;position:absolute;display:none;left:0;top:0;z-index:0"></iframe>
# <!-- END weborama -->
# <script>
#     var callback = function (){
#         grvt_wrapper.checkGravityConsents(
#             function(consentStatus) {
#                 if (consentStatus === true) {
#                     /* YOU SHOULD NOT EDIT THIS PART */
#                     !function(a,b,c){"use strict";function d(a){var b=e[c]||{};e[c]=b,b[a]||(b[a]=function(){e._queue[c].push({method:a,args:Array.prototype.slice.apply(arguments)})})}var e=a.scimhtiraidem||{},f="init call config push pushDefault addProperties addProperty onFinish onStart _reset".split(" ");e._queue=e._queue||{},e._names=e._names||[],e._names.push(c),e._queue[c]=e._queue[c]||[],e._startTime=(new Date).getTime(),e._snippetVersion="2.0";for(var g=0;g<f.length;g++)d(f[g]);a.scimhtiraidem=e,a[c]=e[c];var h=b.createElement("script");h.setAttribute("type","text/javascript"),h.setAttribute("src","//static.mediarithmics.com/tag/1/tag.min.js"),h.setAttribute("async","true"),b.getElementsByTagName("script")[0].parentNode.appendChild(h)}(window,document,"gravity");
#                     /* CUSTOM */
#                     gravity.init({
#                         mode: "VISIT",
#                         site_token: "leq-web17"
#                     });
#                     var dr_properties = {};
#                     if (typeof s18 !== "undefined" && s18!== "") {dr_properties["s18"] = s18;}; // Sport
#                     if (typeof s17 !== "undefined" && s17!== "") {dr_properties["s17"] = s17;}; // Competition
#                     if (typeof s29 !== "undefined" && s29!== "") {dr_properties["s29"] = s29;}; // Keywords redaction
#                     if (typeof s28 !== "undefined" && s28!== "") {dr_properties["s28"] = s28;}; // Type de page
#                     if (typeof s27 !== "undefined" && s27!== "") {dr_properties["s27"] = s27;}; // Presence video
#                     if (typeof s26 !== "undefined" && s26!== "") {dr_properties["s26"] = s26;}; // Presence photo
#                     gravity.push("$page_view", dr_properties);
#
#                 }
#             }
#         );
#     };
#     var script = document.createElement('script');script.src = "https://cdn-alliancegravity.s3.amazonaws.com/js/tag/tag.js";script.onload = callback;document.head.appendChild(script);
# </script>
# <script>var pulpixId=715;!function(e,t){var i=t.createElement("script"),r=t.getElementsByTagName("script")[0];i.src="https://cdn.pulpix.com/static/pulpix.js",i.id="pulpix",i.async=true,i.setAttribute("data-user-id",pulpixId),r.parentNode.insertBefore(i,r)}(window,document);</script>
# <script src="/elements/js/standalone/mediametrie.js"></script>
# <script type="text/javascript">
#     var DFP_site = DFP_site || 'LEQUIPE';
#     var onFocusId = '42314';
#     switch (DFP_site.replace('/','')) {
#         case 'ADRENALINE':
#             onFocusId = '42316';
#             break;
#         case 'JOURNAL-DU-GOLF':
#             onFocusId = '42320';
#             break;
#         case 'VELO-MAG':
#             onFocusId = '42163';
#             break;
#         case 'COACHING':
#             onFocusId = '42318';
#             break;
#     }
#     if(top.ONFOCUS==undefined){
#         top.ONFOCUS = {
#             app_id: onFocusId,
#             predictRP: function(predict_data){
#                 top.ONFOCUS.rp_zones.push(predict_data);
#             },
#             rp_zones : [],
#             tag_s: new Date().getTime()
#         };
#         /*DO NOT MODIFY THE CODE BELOW*/
#         (function(a,b,c,d){d=top.document.createElement("iframe"),d.src="javascript:false",(d.frameElement||d).style.cssText="width: 0; height: 0; border: 0; display:none;",c=top.document.getElementsByTagName("script")[0],c.parentNode.insertBefore(d,c);try{b=d.contentWindow.document}catch(c){a=top.document.domain,d.src="javascript:var d=document.open();d.domain='"+a+"';void(0);",b=d.contentWindow.document}b.open()._l=function(){var b=this.createElement("script");a&&(this.domain=a),b.id="boomr-if-as",b.src=top.window.location.protocol+"//fogl1onf.com/"+top.ONFOCUS.app_id+"/b.js",this.body.appendChild(b)},b.write('<body onload="document._l();">'),b.close()}());
#     }
# </script>
# <script async="async" src="//widgets.outbrain.com/outbrain.js"></script>
# <script>
#     (function(w,d,s,i,n){w[n]=w[n]||{q:[],init:function(o){w[n].initOpts=o;},ready:function(c){w[n].q.push(c);}};
#         setTimeout(function(j,k){if(!d.getElementById(i)){k=d.getElementsByTagName(s)[0];j=d.createElement(s);j.id=i;
#             j.src="https://cdn.by.wonderpush.com/sdk/1.1/wonderpush-loader.min.js";k.parentNode.insertBefore(j,k);}},0);
#     }(window,document,"script","wonderpush-jssdk-loader","WonderPush"));
#     WonderPush.init({
#         webKey: "57a61e98b452199f6555f0fcc3f69935a1880a92ee39d6e466ab79e8f3e5243d",
#         manifestUrl: "/elements/img/favicons/manifest.json",
#         plugins: {
#             "optin-dialog": {
#                 triggers: {
#                     snooze: 30*24*60*60*1000,
#                     minPages: 3
#                 },
#                 hidePoweredBy: true,
#                 title: "Recevez nos informations urgentes en temps réel et ne manquez rien de l'actu sportive",
#                 message: "Vous pourrez vous désinscrire à tout moment.",
#                 positiveButton: "Activer",
#                 negativeButton: "Plus tard",
#                 icon: "https://m.lequipe.fr/img/favicons/favicon-96x96.png",
#                 style: {
#                     position: "fixed",
#                     zIndex: 1000000
#                 }
#             }
#         }
#     });
#     WonderPush.ready(function(WonderPushSDK) {
#         WonderPushSDK.getInstallationCustomProperties().then(function(custom) {
#             if (!("string_subscriptions" in custom)) {
#                 return WonderPushSDK.putInstallationCustomProperties({
#                     string_subscriptions: ["InfoGenerales"]
#                 });
#             }
#         });
#     });
# </script>
# <!-- Linkedin Code -->
# <script type="text/javascript">
#     _linkedin_partner_id = "563788";
#     window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
#     window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#     (function(){var s = document.getElementsByTagName("script")[0];
#         var b = document.createElement("script");
#         b.type = "text/javascript";b.async = true;
#         b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#         s.parentNode.insertBefore(b, s);})();
# </script>
# <noscript>
# <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=563788&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <!-- End Linkedin Code -->
# <script async="" src="//radar.cedexis.com/1/10044/radar.js"></script>
# <script src="/elements/js/standalone/widget.js?20190523145742" type="text/javascript"></script>
# </html>

# %% [markdown]
# Nous avons ainsi récupérer les informations du site sans les enregistrer physiquement dans un fichier, uniquement dans une variable !
#
# Réafficher le titre principal, les sous titres des articles ainsi que leurs descriptions pour vous en persuader

# %%
for p in soup.find_all('h1'):
    print (p.text)
# Out:
# Federer, le grand retour

# %%
for p in soup.find_all('h2', attrs={"class" : "home__colead__title"}):
    print (p.text)
# Out:
#
#             Qui peut contrarier Mercedes ?
#
#
#
#
#             Brest choisit finalement Dall'Oglio
#
#
#
#
#             Mahut, ça se complique
#
#
#
#
#             Tous les matches en direct
#
#
#
#
#             C'est déjà fini pour Kerber
#
#
#
#
#             Auger-Aliassime déclare forfait
#
#
#
#
#             Tsitsipas sans souci
#
#
#
#
#             Humbert n'a pas tenu
#
#
#
#
#
#             Le Top 14 pour Brive ou Bayonne ?
#
#
#
#
#             Cattaneo et Cataldo ont pris le large
#
#
#
#
#             Des feuilles mortes au printemps
#
#
# l'actu Giro en vidéos
#
#
#             Coup double pour Pinot
#
#
#
#
#             Les 500 Miles, une course à étapes
#
#
#
#
#             Tuchel et Mbappé : l'amour vache...
#
#
#
#
#             ...Neymar, la première fêlure
#
#
#
#
#             Villas-Boas, le choix de «Zubi»
#
#
#
#
#             Juninho présenté mardi
#
#
#
#
#             Face au ballon - le rugby
#
#
#
#
#             Les Raptors sont-ils vraiment outsiders ?
#
#
#
#
#             2017 : l'overcut gagnant de Vettel
#
#
#
#
#             Sale temps pour les fans de Leclerc
#
#
#
#
#             Les stats d'une saison XXL
#
#
#
#
#             Toutes les notes de L'Équipe
#
#
#
#
#             Stéphan tiraillé
#
#
#
#
#             Lille avance sur Lukebakio
#
#
#
#
#             Djokovic-Nadal : deux monstres à déloger
#
#
#
#
#             Roland-Garros en chiffres
#
#
#
#
#             Les petits mystères de Djokovic
#
#
#
#
#             «Même moi, je ne sais pas ce qui peut se passer»
#
#
#
#
#             Les favorites au banc d'essai
#
#
#
#
#             Simonne Mathieu, championne de l'ombre
#
#
#
#
#             Posvite a pris l'or
#
#
#
#
#             Un final haletant
#
#
#
#
#             Demandez le programme !
#
#
# l'actu rugby en vidéos
#
#
#             Merling : «On mesurera plus tard»
#
#
#
#
#             A Toulouse les records
#
#
#
#
#             Montpellier qualifié, Castres à la trappe
#
#
#
#
#             Dans les coulisses de la pitlane
#
#
#
#
#             Make America French again
#
#
#
#
#             Daniele ''Der'' Rossi
#
#
#
#
#             Les années Bayern de Ribéry
#
#
# l'actu en vidéos
#
#
#             Le programme et les infos
#
#
#
#
#             Les Mondiaux par les frères Delpero
#
#
#
#
#             Faites le 11 de légende de votre club
#
#
#
#
#             Faites votre 11 de légende de l'OM
#
#
#
#
#             Faites votre 11 de légende de Reims
#
#
#
#
#             Faites votre onze de légende des Verts
#
#
#
#
#             Faites votre onze de légende de l'OGCN
#
#
#
#
#             Faites votre onze de légende de Lille
#
#
#
#
#             Faites votre onze de légende de Nantes
#
#
#
#
#             Faites votre onze de légende de l'OL
#
#
#
#
#             Faites votre onze de légende de Montpellier
#
#
#
#
#             Faites votre onze de légende de l'ASM
#
#
#
#
#             Faites votre onze de légende du PSG
#
#
#
#
#             Faites votre onze de légende de Rennes
#
#
#
#
#             Épisode 3 : Disiz et Hatem Ben Arfa
#
#
#
#
#             Le Stade Français, autopsie d'un échec
#
#
#
#
#             Qui est le « GOAT » du MMA ?
#
#
#
#
#             Vers une finale ASVEL - Monaco ?
#
#
#
#
#             Michael Chang : « Je n'ai servi à la cuillère qu'une fois dans ma vie »
#
#
#
#
#             Sur terre battue, le tennis est un sport de glisse
#
#
#
#
#             Benny Berthet, sauvé de la guerre par le tennis
#
#
#
#
#             Brest se mobilise pour un espoir du club menacé d'expulsion
#
#
#
#
#             À l'entraînement avec Simona Halep, l'athlète complète
#
#
#
#
#             Pour son maillot, le Brésil vote blanc
#
#
# la chaine L’Équipe
# la chaine en replay
#
#
#             «Gourcuff, même là-dessus il avance pas»
#
#
#
#
#             Le guide des 23 Bleues
#
#
#
#
#             IAS : présumés coupables
#
#
#
#
#             Le champion que la France attend
#
#
#
#
#             Guardiola, la loi des 32 minutes
#
#
#
#
#             La Barkley sans pitié
#
#
#
#
#             La fille qui avait un petit moteur dans son vélo
#
#
#
#
#             6 sommets de plus de 8 000m en moins d'un mois
#
#
#
#         Revol gravit l'Everest et le Lhotse en 2 jours
#
#
#         La sélection pente raide de la semaine
#
#
#         Pierre Rémy, champion du monde en reconquête
#
#
#
#             Le nouveau maillot présenté
#
#
#
#         Les chaussures les plus originales des play-offs
#
#
#         Le nouveau maillot dévoilé
#
#
#         Le Ballon d'Or exposé à la Villette
#
#
#
#             Comment se préparer ?
#
#
#
#         Comment améliorer son endurance ?
#
#
#         CrossFit : faut-il s'entraîner à haute intensité ?
#
#
#         Comment maigrir des bras ?
#
#
#
#             Gebremedhin, la foi d'un migrant
#
#
#
#         Les masques anti-pollution en question
#
#
#         En immersion avec Natura4Ever Roubaix Lille Métropole
#
#
#         Absalon : «Rouler, c'est encore un besoin»

# %%
for p in soup.find_all('p', attrs={"class" : "home__colead__details"}):
    print (p.text)
# Out:
#     Le Stade Brestois, de retour en L1, sera entraîné par Olivier Dall'Oglio la saison prochaine même si, ces derniers jours, Christophe Pelissier semblait tenir la corde.
#
#
#
#
#
#
#     Retrouvez ici toutes les informations du jour.
#
#
#     Touché aux adducteurs, le Canadien Félix Auger-Aliassime a déclaré forfait pour Roland-Garros.
#
#
#     Pas de problème pour Stefanos Tsitsipas. Le Grec, tête de série n° 6, est facilement venu à bout de Maximilian Marterer (6-2, 6-2, 7-6 [4]). Il est au deuxième tour de Roland-Garros.
#
#
#     Pour sa première apparition dans le tableau principal à Roland-Garros, le Français Ugo Humbert s'est incliné en quatre sets face à Alexei Popyrin.
#
#
#     Des Brivistes costauds, plus lourds, face à des Bayonnais plus vifs et insouciants ? Opposition de style dans une finale de Pro D2 à suivre en direct commenté.
#
#
#     C'est parti pour la plus longue étape de l'édition 2019 du Giro dont l'arrivée, au terme des 232 km de course, sera jugée sur les rives du lac de Côme. A suivre en direct commenté.
#
#
#     Le Giro poursuit sa route. Au programme de ce dimanche : une étape de 232 km entre Ivrea et Côme, la plus longue de ce Tour d'Italie 2019.
#
#
#     Thibaut Pinot (Groupama - FDJ) s'est facilement imposé au sommet du Grand Colombier, en solitaire, pour remporter le Tour de l'Ain pour la deuxième fois.
#
#
#     Avec un peu plus de 800 km à parcourir, les 500 Miles d'Indianapolis sont une course particulière, composée de plusieurs étapes que Simon Pagenaud, le poleman, et son équipe détaillent.
#
#
#     L'entraîneur du PSG voue une grande admiration à son attaquant. Mais certains de ses choix ont nourri une relation ambiguë.
#
#
#     Le départ anticipé du numéro 10 parisien au Brésil, contre l'avis de Tuchel, constitue un différend inédit entre les deux hommes.
#
#
#     Le technicien portugais est la priorité du directeur sportif de l'OM pour la succession de Rudi Garcia.
#
#
#     Le nouveau directeur sportif de l'OL prend ce dimanche soir l'avion depuis Los Angeles, où il résidait. Il sera présenté officiellement à Lyon mardi.
#
#
#     Gaël Fickou, grand espoir du rugby français se confie sur son sport. Retour en image.
#
#
#     Qualifié pour la première finale de son histoire avec l'avantage du terrain en prime, Toronto ne bénéficie toutefois pas de pronostics favorables avant d'affronter les Golden State Warriors. Ce statut d'outsider est-il vraiment justifié ?
#
#
#     Ferrari vous plonge dans les méandres et les angoisses du travail d'un ingénieur en stratégie en revisitant la course de 2017 et l'''overcut'' victorieux de Sebastian Vettel sur Kimi Räikkönen.
#
#
#     Triste journée pour les amoureux du pilote monégasque. Non seulement ils ne trouvent pas le moindre gadget à l'effigie de leur champion, mais en plus celui-ci a été piégé par son équipe et partira en 15e position ce dimanche.
#
#
#
#
#
#
#     L'entraîneur rennais Julien Stéphan, qui s'est vu proposer une prolongation d'un an, devrait décider en milieu de semaine s'il continue sa mission.
#
#
#     À la recherche d'un successeur à Nicolas Pépé, le club nordiste, qui étudie d'autres pistes, a formulé une offre contractuelle au Belge de Watford. La concurrence est forte.
#
#
#
#
#     Prize money, records à battre, stats insolites, il y a plusieurs façons de vivre le lancement du tournoi parisien.
#
#
#     L'incontestable numéro 1 mondial Novak Djokovic  a traversé un trou d'air de trois mois avant de se ressaisir, pile au bon moment.
#
#
#     Meilleur Français sur terre battue cette saison, avec deux titres remportés à Marrakech, puis à Lyon, l'imprévisible Avignonnais assume tout.
#
#
#     De la complète Simona Halep à la terrienne Kiki Bertens en passant par Karolina Pliskova et une éventuelle surprise de Serena Williams, les favorites sont légion à Roland-Garros cette année.
#
#
#     Double vainqueure du tournoi, en 1938 et 1939, la Française a été longtemps oubliée malgré son parcours hors du commun. Le nouveau court de Roland-Garros porte son nom.
#
#
#     La Française Fanny-Estelle Posvite s'est imposée dimanche chez les moins de 78 kg à l'occasion du Grand Prix de Hohhot (Chine). Dans la même catégorie, Audrey Tcheuméo a échoué à prendre le bronze.
#
#
#     La 26e journée du Top 14 a souri à Montpellier et à La Rochelle, mais pas à Castres. Pendant une heure et demie, le classement a évolué sans cesse, donnant des espoirs aux candidats pour la phase finale.
#
#
#     Battu à domicile par Toulon (16-25), le champion de France, Castres, ne disputera pas la phase finale. Sur leur terrain, Lyon et le Racing 92 recevront en barrages respectivement Montpellier, qualifié in extremis, et La Rochelle.
#
#
#     Vincent Merling, le président rochelais, savoure la qualification de son équipe et rappelle l'événement exceptionnel que cela représente pour le club et la ville.
#
#
#     Record de points au classement (98) et record d'essais inscrits (102) : le Stade Toulousain, en pulvérisant Perpignan (42-7), termine la saison régulière sur une note très offensive.
#
#
#     Victorieux à Clermont (27-28), samedi lors de la dernière journée, Montpellier se qualifie in extremis tandis que Castres s'incline devant Toulon (16-25). De son côté, La Rochelle a surclassé Bordeaux-Bègles (81-12).
#
#
#     La 103e édition des 500 miles d'Indianapolis partira dimanche à 18h45 (heure française). Découvrez les coulisses de la pitlane de ce circuit mythique.
#
#
#     Pagenaud et Bourdais, respectivement en pole et septième sur la grille, ont chacun une vraie chance de devenir le premier Français à remporter les 500 Miles d'Indianapolis depuis un siècle.
#
#
#     Le milieu italien disputera dimanche soir (20h30) face à Parme, bien malgré lui, son dernier match avec l'AS Rome.
#
#
#     Arrivé en 2007 au Bayern Munich, Franck Ribéry est devenu une icône au fil des douze ans passés dans le club allemand.
#
#
#     Les Championnats du monde ISA de longboard débutent ce dimanche sur le spot de la Côte des Basques à Biarritz (26 mai - 2 juin). Présentation.
#
#
#     Les Mondiaux de longboard vont se dérouler sur la Côte des Basques à Biarritz du 26 mai au 2 juin. Présentation par les frères Delpero, favoris de la compétition.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Deux artistes parfois incompris sont ici réunis : le rappeur Disiz (41 ans) et le footballeur Hatem Ben Arfa (32 ans). Les deux hommes ont percé, brillé très jeune mais leur carrière est, depuis, tout sauf linéaire. Rencontre avec deux créatifs, touchants de sincérité.
#
#
#     Voilà quatre saisons de suite que les phases finales se refusent à eux. Cette année, les Parisiens avaient pourtant l'argent, des recrues de poids et un coach à la stature internationale. Alors, que s'est-il passé ?
#
#
#
#
#     Les play-offs du championnat de France de basket débutent ce vendredi. Deux grands favoris semblent se détacher : l'ASVEL, premier de la saison régulière, et Monaco, quasiment invincible lors de la phase retour.
#
#
#     En 1989, un gamin de 17 ans humiliait avec un service improbable le n° 1 mondial, Ivan Lendl, avant de remporter Roland-Garros pour écrire l'un des plus grands exploits de l'histoire du sport.Trente ans après, l'Américain nous raconte avec émotion la quinzaine qui a changé sa vie.
#
#
#     L'art de glisser est une composante essentielle du jeu et du spectacle sur terre battue. Certains joueurs le pratiquent instinctivement. D'autres y sont complètement réfractaires.
#
#
#     Capitaine de Coupe Davis de 1954 à 1965, Benjamin Berthet, dit Benny, a été adulé par ceux qui ont joué sous ses ordres. Mais son fait de gloire remonte à la Seconde Guerre mondiale. De confession juive, il a remporté le tournoi de sa vie derrière les barbelés d'un camp en Allemagne.
#
#
#     Abandonné par un faux agent en 2015, le jeune footballeur ivoirien Marc-Olivier Glazaï, 18 ans, avait réussi à s'insérer au Stade Brestois. Il est aujourd'hui frappé d'une obligation de quitter le territoire français, et soutenu par le club.
#
#
#     Rapide et endurante, la Roumaine Simona Halep a enlevé Roland-Garros 2018 grâce à de vraies qualités d'athlète. Et dire qu'elle déteste la préparation physique... Nous sommes allés vérifier.
#
#
#     Maudit depuis près de soixante-dix ans, le maillot blanc de la Seleçao resurgit le mois prochain lors de la Copa America. Avec l'espoir qu'il soit moins politisé que la célèbre tunique jaune
#
#
#     Découvrez le onzième épisode de « Varatata », le programme de pastilles humoristiques autour du VAR de L'Équipe et Football Total.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     L'alpiniste népalais Nims Dai a réussi ce vendredi l'ascension du Makalu (8 481 m), dans l'Himalaya, bouclant ainsi son sixième sommet de plus de 8 000 mètres en moins d'un mois. Il vise un record stratosphérique : réaliser les 14 plus hauts sommets en moins de 7 mois.
#
#
#     L'OM vient de dévoiler sa nouvelle tenue domicile pour la saison 2019-2020.
#
#
#     The Mud Day se déroulera au camp militaire de Beynes, à l'est de Paris les samedi 15 et dimanche 16 juin 2019. Trois semaines restent pour optimiser sa condition physique.
#
#
#     Awet Gebremedhin a fui l'Érythrée et a vécu clandestinement en Suède dans le seul but de devenir un jour coureur professionnel. Il porte aujourd'hui le maillot d'Israël Cycling Academy.
